# %% [markdown]
# # VGG Implementation - Train on ImageNet 2012
# - Source Literature: [VGGNet Paper](https://arxiv.org/pdf/1409.1556.pdf)
# - Data Loader Notebook: `VGGNet_Data_Loader.ipynb`
# - Vanialla Model and Fused Model Prototypes: `VGGNet_Prototype_Model.ipynb`
#
# ## Dataset Directory Structure & Requirements
#
# Enough HDD/SSD space is required for the following:
# - Downloading Raw Dataset - 156.8 GB
# - Convert to TFRecord and Store - 155.9 GB
# - Total Storage Required - 312.7 GB
#
# An SSD is recommended and a Mechanical HDD should be avoided since it will slow down the data loader significantly.
#
# ### Dataset Download
#
# ImageNet Download Link: [Download ImageNet Dataset](https://image-net.org/download-images)
#
# - Download Train Images (Required): `ILSVRC2012_img_train.tar` - Size 137.7 GB
# - Download Val Images (Required): `ILSVRC2012_img_val.tar` - Size 6.3 GB
# - Download Train Images (Optional): `ILSVRC2012_img_test.tar` - Size 12.7 GB
#
# ### Raw/Source Dataset Directory Structure
# Download the dataset from the above link and put it in the folder like shown:
# ```
# imagenet2012/
# ├── ILSVRC2012_img_test.tar
# ├── ILSVRC2012_img_train.tar
# └── ILSVRC2012_img_val.tar
# ```
#
# ### Processed/Destination Dataset Directory Structure
# Create another folder and create the folders `data`, `download` & `extracted` like shown:
# ```
# imagenet/
# ├── data/
# ├── downloaded/
# └── extracted/
# ```

# %%
import os

os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "1"

import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint

plt.rcParams["figure.figsize"] = 30, 30

# %% [markdown]
# # ImageNet Data Loader

# %%
class ImageNetDataLoader:
    def __init__(
        self,
        source_data_dir: str,
        dest_data_dir: str,
        split: str = "train",
        image_dims: tuple = (224, 224),
        num_classes=1000
    ) -> None:
        """
        __init__
        - Instance Variable Initialization
        - Download and Set Up Dataset (One Time Operation)
        - Use TFDS to Load and convert the ImageNet Dataset
        
        Args:
            source_data_dir (str): Path to Downloaded tar files
            dest_data_dir (str): Path to the location where the dataset will be unpacked
            spliit (str): Split to load as. Eg. train, test, train[:80%]. Defaults to "train"
            image_dims (tuple, optional): Image Dimensions (width & height). Defaults to (224, 224).
            num_classes (int): Number of Classes contained in this dataset. Defaults to 1000
        """
        
        # Constants
        self.NUM_CLASSES=num_classes
        self.BATCH_SIZE = None
        self.NUM_CHANNELS = 3
        self.LABELS = []
        self.LABELMAP = {}
        self.AUTOTUNE = tf.data.experimental.AUTOTUNE
        self.WIDTH, self.HEIGHT = image_dims    
        
        # Download Config
        download_config = tfds.download.DownloadConfig(
            extract_dir=os.path.join(dest_data_dir, 'extracted'),
            manual_dir=source_data_dir
        )

        download_and_prepare_kwargs = {
            'download_dir': os.path.join(dest_data_dir, 'downloaded'),
            'download_config': download_config,
        }
        
        # TFDS Data Loader (This step also performs dataset conversion to TFRecord)
        self.dataset, self.info = tfds.load(
            'imagenet2012', 
            data_dir=os.path.join(dest_data_dir, 'data'),         
            split=split, 
            shuffle_files=True, 
            download=True, 
            as_supervised=True,
            with_info=True,
            download_and_prepare_kwargs=download_and_prepare_kwargs
        )
    
    
    def preprocess_image(self, image, label):
        """
        preprocess_image
        
        Process the image and label to perform the following operations:
        - Min Max Scale the Image (Divide by 255)
        - Convert the numerical values of the lables to One Hot Encoded Format
        - Resize the image to 224, 224
        
        Args:
            image (Image Tensor): Raw Image
            label (Tensor): Numeric Labels 1, 2, 3, ...
        Returns:
            tuple: Scaled Image, One-Hot Encoded Label
        """
        image = tf.cast(image, tf.uint8)
        image = tf.image.resize(image, [self.HEIGHT, self.WIDTH])
        image = image / tf.math.reduce_max(image)
        label = tf.one_hot(indices=label, depth=self.NUM_CLASSES)
        return image, label
    
    @tf.function
    def augment_batch(self, image, label) -> tuple:
        """
        augment_batch
        Image Augmentation for Training:
        - Random Contrast
        - Random Brightness
        - Random Hue (Color)
        - Random Saturation
        - Random Horizontal Flip
        - Random Reduction in Image Quality
        - Random Crop
        Args:
            image (Tensor Image): Raw Image
            label (Tensor): Numeric Labels 1, 2, 3, ...
        Returns:
            tuple: Augmented Image, Numeric Labels 1, 2, 3, ...
        """
        if tf.random.normal([1]) < 0:
            image = tf.image.random_contrast(image, 0.2, 0.9)
        if tf.random.normal([1]) < 0:
            image = tf.image.random_brightness(image, 0.2)
        if self.NUM_CHANNELS == 3 and tf.random.normal([1]) < 0:
            image = tf.image.random_hue(image, 0.3)
        if self.NUM_CHANNELS == 3 and tf.random.normal([1]) < 0:
            image = tf.image.random_saturation(image, 0, 15)
        
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_jpeg_quality(image, 10, 100)

        return image, label
    
    def get_dataset_size(self) -> int:
        """
        get_dataset_size
        Get the Dataset Size (Number of Images)
        Returns:
            int: Total Number of images in Dataset
        """
        return len(self.dataset)
    
    def get_num_steps(self) -> int:
        """
        get_num_steps
        Get the Number of Steps Required per Batch for Training
        Raises:
            AssertionError: Dataset Generator needs to be Initialized First
        Returns:
            int: Number of Steps Required for Training Per Batch
        """
        if self.BATCH_SIZE is None:
            raise AssertionError(
                f"Batch Size is not Initialized. Call this method only after calling: {self.dataset_generator}"
            )
        num_steps = self.get_dataset_size() // self.BATCH_SIZE + 1
        return num_steps
    
    def dataset_generator(self, batch_size=32, augment=False):
        """
        dataset_generator
        Create the Data Loader Pipeline and Return a Generator to Generate Datsets
        Args:
            batch_size (int, optional): Batch Size. Defaults to 32.
            augment (bool, optional): Enable/Disable Augmentation. Defaults to False.
        Returns:
            Tf.Data Generator: Dataset Generator
        """
        self.BATCH_SIZE = batch_size

        dataset = self.dataset.apply(tf.data.experimental.ignore_errors())

        dataset = dataset.shuffle(batch_size * 10)
        dataset = dataset.repeat()
               
        if augment:
            dataset = dataset.map(self.augment_batch, num_parallel_calls=self.AUTOTUNE)
        
        dataset = dataset.map(self.preprocess_image, num_parallel_calls=self.AUTOTUNE)
        
        dataset = dataset.batch(batch_size)
        dataset = dataset.prefetch(buffer_size=self.AUTOTUNE)

        return dataset
    
    def visualize_batch(self, augment=True) -> None:
        """
        visualize_batch
        Dataset Sample Visualization
        - Supports Augmentation
        - Automatically Adjusts for Grayscale Images
        Args:
            augment (bool, optional): Enable/Disable Augmentation. Defaults to True.
        """
        if self.NUM_CHANNELS == 1:
            cmap = "gray"
        else:
            cmap = "viridis"

        dataset = self.dataset_generator(batch_size=36, augment=augment)
        image_batch, label_batch = next(iter(dataset))
        image_batch, label_batch = (
            image_batch.numpy(),
            label_batch.numpy(),
        )

        for n in range(len(image_batch)):
            ax = plt.subplot(6, 6, n + 1)
            plt.imshow(image_batch[n], cmap=cmap)
            plt.title(np.argmax(label_batch[n]))
            plt.axis("off")
        plt.show()

# %% [markdown]
# # Initialize VGGNet (Choose Architecture)

# %%
from vgg_nets import VGG11, VGG13, VGG16_1, VGG16, VGG19

vgg_net = VGG11(shape=(224, 224, 3), classes=1000)
vgg_net.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# softmax (Softmax)            (None, 1000)              0
# =================================================================
# Total params: 132,863,336
# Trainable params: 132,863,336
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training Callbacks
# - Early Stopping - Stop Training if Validation Accuracy Stops Increasing
# - Model Checkpoint - Save Model Weights (Model) if Validation Accuracy improves
# - Reduce Learning Rate - As per the Author Specifications, Learning Rate is Reduced by a factor of 10 if loss validation accuracy does not improve
# - Tensorboard - Log the Training and Validation Metrics on Tensorboard for Training Analysis

# %%
# Callbacks
early_stop_cb = tf.keras.callbacks.EarlyStopping(
    monitor="val_categorical_accuracy",
    min_delta=0,
    patience=10,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)
model_ckpt_cb = tf.keras.callbacks.ModelCheckpoint(
    "weights/vgg_net.{epoch:02d}-{val_categorical_accuracy:.2f}-{val_loss:.2f}.h5",
    monitor="val_categorical_accuracy",
    verbose=0,
    save_best_only=True,
    save_weights_only=False,
    mode="auto",
    save_freq="epoch",
)
reduce_lr_cb = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_categorical_accuracy",
    factor=0.1,
    patience=2,
    verbose=0,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=10e-8,
)
tensorboard_cb = tf.keras.callbacks.TensorBoard(
    log_dir="tb_logs/",
    histogram_freq=2,
    write_graph=True,
    write_images=False,
    update_freq="epoch",
    profile_batch=2,
    embeddings_freq=2,
    embeddings_metadata=None,
)
callbacks = [early_stop_cb, model_ckpt_cb, reduce_lr_cb, tensorboard_cb]

# %% [markdown]
# # Training and Validation Metrics
#
# ### Legend:
# - **TP** - True Positive
# - **FP** - False Positive
# - **TN** - True Negative
# - **FN** - False Negative
#
# ### Metrices:
# - **Categorical Accuracy** = $\frac{TP+FP}{TP+FP+TN+FN}$
# - **Precision** = $\frac{TP}{TP+FP}$
# - **Recall** = $\frac{TP}{TP+FN}$
# - **F1 Score** = $2*\frac{Precision*Recall}{Precision+Recall}$

# %%
# Metrics
metrics = [
    tf.keras.metrics.CategoricalAccuracy(),
    tf.keras.metrics.FalseNegatives(),
    tf.keras.metrics.FalsePositives(),
    tf.keras.metrics.Precision(),
    tf.keras.metrics.Recall(),
    tfa.metrics.F1Score(num_classes=1000)
]

# %% [markdown]
# # Mixed Precision Training
# Enable Mixed Precision Training for Supported GPUs to utilize the optimized Tensor Cores for Matrix Operations.
#
# Read About Tensor Cores Here: [Tensor Cores - Nvidia Developer](https://www.nvidia.com/en-in/data-center/tensor-cores/)

# %%
# Mixed Precision
tf.keras.mixed_precision.set_global_policy("mixed_float16")
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 2080 Ti, compute capability 7.5

# %% [markdown]
# # Initialize Data Loader for Training & Validation

# %%
# Constants
BATCH_SIZE = 128


# Init Data Loaders
train_data_loader = ImageNetDataLoader(
        source_data_dir = "/mnt/data/pycodes/Dataset/imagenet2012",
        dest_data_dir = "/home/ani/Documents/datasets/imagenet",
        split = "train",
        image_dims = (224, 224),
)

val_data_loader = ImageNetDataLoader(
        source_data_dir = "/mnt/data/pycodes/Dataset/imagenet2012",
        dest_data_dir = "/home/ani/Documents/datasets/imagenet",
        split = "validation",
        image_dims = (224, 224),
)

train_generator = train_data_loader.dataset_generator(batch_size=BATCH_SIZE, augment=False)
val_generator = val_data_loader.dataset_generator(batch_size=BATCH_SIZE, augment=False)

train_steps = train_data_loader.get_num_steps()
val_steps = val_data_loader.get_num_steps()

# %% [markdown]
# # Compile Model and Start Training

# %%
# Constants
EPOCHS = 200

# Compile & Train
vgg_net.compile(
    loss=tf.keras.losses.CategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.SGD(
        learning_rate=0.01, momentum=0.9, nesterov=False, name='SGD'
    ),
    metrics=metrics,
)

history = vgg_net.fit(
    epochs=EPOCHS,
    x=train_generator,
    steps_per_epoch=train_steps,
    validation_data=val_generator,
    validation_steps=val_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/200
# 10010/10010 [==============================] - 3778s 376ms/step - loss: 6.7896 - categorical_accuracy: 0.0037 - false_negatives: 640719.5064 - false_positives: 48.2956 - precision: 0.2479 - recall: 4.2859e-05 - f1_score: 0.0028 - val_loss: 5.0878 - val_categorical_accuracy: 0.0777 - val_false_negatives: 49868.0000 - val_false_positives: 132.0000 - val_precision: 0.5769 - val_recall: 0.0036 - val_f1_score: 0.0554
# Epoch 2/200
# 10010/10010 [==============================] - 3833s 383ms/step - loss: 4.6560 - categorical_accuracy: 0.1199 - false_negatives: 623867.0359 - false_positives: 10904.5785 - precision: 0.5792 - recall: 0.0199 - f1_score: 0.1045 - val_loss: 3.4463 - val_categorical_accuracy: 0.2765 - val_false_negatives: 45396.0000 - val_false_positives: 1602.0000 - val_precision: 0.7438 - val_recall: 0.0930 - val_f1_score: 0.2582
# Epoch 3/200
# 10010/10010 [==============================] - 3885s 388ms/step - loss: 3.3116 - categorical_accuracy: 0.2910 - false_negatives: 554222.9863 - false_positives: 39525.1711 - precision: 0.6829 - recall: 0.1277 - f1_score: 0.2787 - val_loss: 2.8057 - val_categorical_accuracy: 0.3801 - val_false_negatives: 40005.0000 - val_false_positives: 3368.0000 - val_precision: 0.7489 - val_recall: 0.2007 - val_f1_score: 0.3649
# Epoch 4/200
# 10010/10010 [==============================] - 3742s 374ms/step - loss: 2.6769 - categorical_accuracy: 0.3966 - false_negatives: 489803.3187 - false_positives: 56702.7293 - precision: 0.7256 - recall: 0.2322 - f1_score: 0.3877 - val_loss: 2.4999 - val_categorical_accuracy: 0.4378 - val_false_negatives: 36852.0000 - val_false_positives: 3860.0000 - val_precision: 0.7737 - val_recall: 0.2637 - val_f1_score: 0.4237
# Epoch 5/200
# 10010/10010 [==============================] - 3723s 372ms/step - loss: 2.2957 - categorical_accuracy: 0.4636 - false_negatives: 442215.3424 - false_positives: 65728.4521 - precision: 0.7517 - recall: 0.3095 - f1_score: 0.4561 - val_loss: 2.3575 - val_categorical_accuracy: 0.4621 - val_false_negatives: 35267.0000 - val_false_positives: 4197.0000 - val_precision: 0.7788 - val_recall: 0.2953 - val_f1_score: 0.4509
# Epoch 6/200
# 10010/10010 [==============================] - 3709s 371ms/step - loss: 2.0252 - categorical_accuracy: 0.5147 - false_negatives: 404757.8910 - false_positives: 71171.6608 - precision: 0.7695 - recall: 0.3704 - f1_score: 0.5087 - val_loss: 2.2822 - val_categorical_accuracy: 0.4804 - val_false_negatives: 33405.0000 - val_false_positives: 4946.0000 - val_precision: 0.7709 - val_recall: 0.3325 - val_f1_score: 0.4684
# Epoch 7/200
# 10010/10010 [==============================] - 3693s 369ms/step - loss: 1.8132 - categorical_accuracy: 0.5537 - false_negatives: 374082.7798 - false_positives: 75617.8211 - precision: 0.7811 - recall: 0.4206 - f1_score: 0.5483 - val_loss: 2.2384 - val_categorical_accuracy: 0.4911 - val_false_negatives: 32782.0000 - val_false_positives: 5206.0000 - val_precision: 0.7683 - val_recall: 0.3450 - val_f1_score: 0.4806
# Epoch 8/200
# 10010/10010 [==============================] - 3675s 367ms/step - loss: 1.6666 - categorical_accuracy: 0.5815 - false_negatives: 350538.2915 - false_positives: 78703.1082 - precision: 0.7887 - recall: 0.4576 - f1_score: 0.5770 - val_loss: 2.2008 - val_categorical_accuracy: 0.4971 - val_false_negatives: 31871.0000 - val_false_positives: 5830.0000 - val_precision: 0.7572 - val_recall: 0.3632 - val_f1_score: 0.4879
# Epoch 9/200
# 10010/10010 [==============================] - 3615s 361ms/step - loss: 1.5357 - categorical_accuracy: 0.6071 - false_negatives: 330191.7851 - false_positives: 81614.3906 - precision: 0.7948 - recall: 0.4920 - f1_score: 0.6032 - val_loss: 2.2248 - val_categorical_accuracy: 0.4931 - val_false_negatives: 32151.0000 - val_false_positives: 5708.0000 - val_precision: 0.7582 - val_recall: 0.3576 - val_f1_score: 0.4841
# Epoch 10/200
# 10010/10010 [==============================] - 3609s 361ms/step - loss: 1.4470 - categorical_accuracy: 0.6242 - false_negatives: 315298.0463 - false_positives: 83645.6152 - precision: 0.7985 - recall: 0.5155 - f1_score: 0.6203 - val_loss: 2.2396 - val_categorical_accuracy: 0.4938 - val_false_negatives: 31209.0000 - val_false_positives: 6622.0000 - val_precision: 0.7399 - val_recall: 0.3764 - val_f1_score: 0.4865
# Epoch 11/200
# 10010/10010 [==============================] - 3609s 360ms/step - loss: 1.0208 - categorical_accuracy: 0.7204 - false_negatives: 226807.1409 - false_positives: 74913.2367 - precision: 0.8443 - recall: 0.6372 - f1_score: 0.7173 - val_loss: 2.1498 - val_categorical_accuracy: 0.5268 - val_false_negatives: 28119.0000 - val_false_positives: 8475.0000 - val_precision: 0.7213 - val_recall: 0.4382 - val_f1_score: 0.5202
# Epoch 12/200
# 10010/10010 [==============================] - 3615s 361ms/step - loss: 0.8129 - categorical_accuracy: 0.7688 - false_negatives: 189653.1846 - false_positives: 69366.8619 - precision: 0.8665 - recall: 0.7024 - f1_score: 0.7663 - val_loss: 2.1846 - val_categorical_accuracy: 0.5285 - val_false_negatives: 27540.0000 - val_false_positives: 9302.0000 - val_precision: 0.7076 - val_recall: 0.4497 - val_f1_score: 0.5216
# Epoch 13/200
# 10010/10010 [==============================] - 3614s 361ms/step - loss: 0.7054 - categorical_accuracy: 0.7953 - false_negatives: 168660.5927 - false_positives: 65947.1977 - precision: 0.8782 - recall: 0.7371 - f1_score: 0.7931 - val_loss: 2.2213 - val_categorical_accuracy: 0.5297 - val_false_negatives: 27076.0000 - val_false_positives: 9940.0000 - val_precision: 0.6980 - val_recall: 0.4590 - val_f1_score: 0.5234
# Epoch 14/200
# 10010/10010 [==============================] - 3614s 361ms/step - loss: 0.6271 - categorical_accuracy: 0.8146 - false_negatives: 152060.5620 - false_positives: 62565.5827 - precision: 0.8871 - recall: 0.7627 - f1_score: 0.8126 - val_loss: 2.2673 - val_categorical_accuracy: 0.5302 - val_false_negatives: 26808.0000 - val_false_positives: 10507.0000 - val_precision: 0.6887 - val_recall: 0.4644 - val_f1_score: 0.5241
# Epoch 15/200
# 10010/10010 [==============================] - 3615s 361ms/step - loss: 0.5664 - categorical_accuracy: 0.8293 - false_negatives: 138650.0911 - false_positives: 59883.7140 - precision: 0.8935 - recall: 0.7830 - f1_score: 0.8275 - val_loss: 2.3199 - val_categorical_accuracy: 0.5302 - val_false_negatives: 26552.0000 - val_false_positives: 11200.0000 - val_precision: 0.6772 - val_recall: 0.4695 - val_f1_score: 0.5238
# Epoch 16/200
# 10010/10010 [==============================] - 3618s 361ms/step - loss: 0.5066 - categorical_accuracy: 0.8452 - false_negatives: 125653.6599 - false_positives: 56882.4531 - precision: 0.9010 - recall: 0.8040 - f1_score: 0.8434 - val_loss: 2.3773 - val_categorical_accuracy: 0.5293 - val_false_negatives: 26327.0000 - val_false_positives: 11843.0000 - val_precision: 0.6670 - val_recall: 0.4740 - val_f1_score: 0.5231
# Epoch 17/200
# 10010/10010 [==============================] - 3760s 376ms/step - loss: 0.4409 - categorical_accuracy: 0.8633 - false_negatives: 110751.5414 - false_positives: 51341.8359 - precision: 0.9115 - recall: 0.8261 - f1_score: 0.8617 - val_loss: 2.4173 - val_categorical_accuracy: 0.5316 - val_false_negatives: 26051.0000 - val_false_positives: 12277.0000 - val_precision: 0.6615 - val_recall: 0.4795 - val_f1_score: 0.5258
# Epoch 18/200
# 10010/10010 [==============================] - 3738s 373ms/step - loss: 0.4241 - categorical_accuracy: 0.8684 - false_negatives: 106600.7453 - false_positives: 50750.9310 - precision: 0.9135 - recall: 0.8339 - f1_score: 0.8670 - val_loss: 2.4359 - val_categorical_accuracy: 0.5313 - val_false_negatives: 25984.0000 - val_false_positives: 12420.0000 - val_precision: 0.6596 - val_recall: 0.4808 - val_f1_score: 0.5255
# Epoch 19/200
#  9599/10010 [===========================>..] - ETA: 2:33 - loss: 0.4163 - categorical_accuracy: 0.8700 - false_negatives: 100664.0823 - false_positives: 48523.6206 - precision: 0.9138 - recall: 0.8362 - f1_score: 0.8685
